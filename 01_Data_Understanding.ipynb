# %% [markdown]
# # Data Understanding
# This notebook loads the e-commerce dataset and inspects its structure, data types, summary statistics, missing values, and duplicate records.

# %%
# Load pandas for data manipulation.
import pandas as pd

# Set option to display all columns and format float values to two decimal places (to avoid scientific notation).
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
# Read the raw e-commerce dataset from the project dataset folder.
ecommerce_df = pd.read_csv(r'dataset/raw/ecommerce_dataset_+1m.csv')

# %%
# DIsplay a random sample of 10 rows from the dataset to get an overview of the data.
ecommerce_df.sample(10)
# Out:
#          order_id                  order_date  order_year  order_month  \
# 501720  ORD-U9I6Z  2024-09-11 00:16:55.038476        2024            9
# 384708  ORD-JAM41  2025-06-26 10:53:53.804012        2025            6
# 578705  ORD-A6XCJ  2024-09-15 00:53:19.915484        2024            9
# 367462  ORD-D60KZ  2024-10-18 17:15:52.063114        2024           10
# 73519   ORD-I6UQP  2025-12-29 20:24:22.552777        2025           12
# 345424  ORD-V25RZ  2024-10-14 23:18:30.577879        2024           10
# 459325  ORD-Q8MX0  2024-09-05 00:16:45.702727        2024            9
# 440594  ORD-J9L65  2025-02-17 18:46:27.494433        2025            2
# 916415  ORD-T1H5O  2025-09-10 09:07:04.283500        2025            9
# 484335  ORD-CJEQ8  2025-05-25 02:21:16.686243        2025            5
#
#         order_day  order_hour  order_minute  order_second is_weekend  \
# 501720         11           0            16            55         No
# 384708         26          10            53            53         No
# 578705         15           0            53            19        Yes
# 367462         18          17            15            52         No
# 73519          29          20            24            22         No
# 345424         14          23            18            30         No
# 459325          5           0            16            45         No
# 440594         17          18            46            27         No
# 916415         10           9             7             4         No
# 484335         25           2            21            16        Yes
#
#        order_status return_reason customer_id     customer_name  gender  age  \
# 501720    Completed           NaN   CUS-QW9A4      Amanda Hayes  Female   41
# 384708    Completed           NaN   CUS-XB35G     William Mason    Male   50
# 578705     Returned  Changed Mind   CUS-90PK9    Elizabeth Vega  Female   46
# 367462      Pending           NaN   CUS-YKN10    Brittany Weiss  Female   37
# 73519     Cancelled           NaN   CUS-O154K  Kristen Diaz DDS  Female   40
# 345424    Cancelled           NaN   CUS-B0IP5    Jeffrey Fisher    Male   45
# 459325    Completed           NaN   CUS-RM7BJ  Sarah Taylor DVM  Female   52
# 440594    Completed           NaN   CUS-3QBI2   Monica Williams  Female   52
# 916415    Completed           NaN   CUS-U93DQ       Gary Thomas    Male   31
# 484335    Completed           NaN   CUS-CM7AB      Shelby Banks  Female   21
#
#        customer_segment        country       city  customer_loyalty_score  \
# 501720          Regular          Italy      Milan                    6.10
# 384708              VIP  United States   New York                   62.90
# 578705          Premium         Canada     Ottawa                    2.70
# 367462          Premium      Australia  Melbourne                   42.80
# 73519           Premium        Belgium   Brussels                   97.50
# 345424          Regular  United States    Houston                   94.70
# 459325          Regular        Germany     Munich                   80.50
# 440594          Regular      Australia      Perth                   57.10
# 916415          Regular          Spain  Barcelona                   96.30
# 484335          Regular         France      Paris                    4.40
#
#         total_orders_by_customer account_creation_date product_id  \
# 501720                        42            2023-04-17   PRD-8Q7M
# 384708                        25            2022-08-24   PRD-FX50
# 578705                         1            2023-10-04   PRD-XGJX
# 367462                        36            2024-01-10   PRD-89FX
# 73519                         45            2022-01-16   PRD-CA2E
# 345424                        34            2022-09-10   PRD-ZU3J
# 459325                        42            2021-03-30   PRD-KPDD
# 440594                        30            2021-12-20   PRD-8PU1
# 916415                        38            2024-02-23   PRD-1YAF
# 484335                        21            2025-05-14   PRD-72YD
#
#                           product_name     category sub_category     brand  \
# 501720           Wireless Mouse 2.4GHz  Electronics      Laptops     Apple
# 384708            Denim Jeans Slim Fit     Clothing        Shoes    Adidas
# 578705           Phone Case Shockproof  Electronics      Tablets       JBL
# 367462               Tennis Balls Pack       Sports      Outdoor      Nike
# 73519                 Portable SSD 1TB  Electronics        Audio  Logitech
# 345424            Smart Watch Series 8  Electronics      Laptops     GoPro
# 459325            Smart Watch Series 8  Electronics  Accessories     Nikon
# 440594                    Baseball Cap     Clothing  Accessories     GoPro
# 916415                  USB Hub 7-Port  Electronics  Accessories      Nike
# 484335  Gaming Mechanical Keyboard RGB  Electronics  Smartphones   Philips
#
#         product_rating_avg  product_reviews_count  stock_quantity  \
# 501720                3.50                   2498             612
# 384708                4.00                   1217             761
# 578705                3.50                    751              25
# 367462                3.10                   1927             381
# 73519                 4.10                   4112             331
# 345424                4.60                   3365             686
# 459325                4.30                    607             237
# 440594                3.30                   4568             938
# 916415                3.70                   4199             679
# 484335                3.70                   1576             406
#
#         unit_price_usd  quantity  discount_percent  discount_amount_usd  \
# 501720           27.51         3                 0                 0.00
# 384708           28.18         3                 0                 0.00
# 578705          360.16         4                 0                 0.00
# 367462          114.07         5                 0                 0.00
# 73519           414.38         2                10                82.88
# 345424          286.43         4                 0                 0.00
# 459325          452.91         5                 0                 0.00
# 440594           53.48         1                10                 5.35
# 916415          243.11         4                 0                 0.00
# 484335          114.73         2                10                22.95
#
#         total_price_usd  cost_usd  profit_usd  tax_usd currency  \
# 501720            82.53     46.41       36.12     4.91      USD
# 384708            84.54     47.13       37.41     4.34      USD
# 578705         1,440.64    740.44      700.20   124.42      USD
# 367462           570.35    328.65      241.70    56.15      USD
# 73519            745.88    413.14      332.74    65.80      USD
# 345424         1,145.72    471.20      674.52   105.96      USD
# 459325         2,264.55  1,408.40      856.15   217.35      USD
# 440594            48.13     35.85       12.28     3.62      USD
# 916415           972.44    534.72      437.72    51.55      USD
# 484335           206.51    131.18       75.33    13.90      USD
#
#        payment_method payment_status installment_plan shipping_method  \
# 501720         PayPal           Paid               No        Next Day
# 384708    Credit Card           Paid               No        Next Day
# 578705  Bank Transfer           Paid               No        Standard
# 367462    Credit Card        Pending               No         Economy
# 73519          PayPal           Paid               No         Express
# 345424     Debit Card         Failed               No         Economy
# 459325         PayPal           Paid               No         Economy
# 440594      Apple Pay           Paid               No        Next Day
# 916415      Apple Pay           Paid              Yes         Economy
# 484335    Credit Card           Paid              Yes        Standard
#
#         shipping_cost_usd  delivery_days shipping_country warehouse_location  \
# 501720               6.41              2            Italy                 UK
# 384708              24.08              3    United States                 UK
# 578705              18.53             12           Canada           USA-East
# 367462               9.23             14        Australia           USA-West
# 73519               20.84              9          Belgium       Asia-Pacific
# 345424              16.34              7    United States           USA-West
# 459325              13.63              2          Germany           USA-East
# 440594               6.53              6        Australia           USA-East
# 916415               5.50             10            Spain       Asia-Pacific
# 484335               8.68              2           France         EU-Central
#
#        delivery_status  rating review_sentiment     customer_feedback  \
# 501720      In Transit       1         Negative    Highly recommended
# 384708      In Transit       1         Negative        Great product!
# 578705       Delivered       1         Negative         Fast delivery
# 367462       Delivered       2         Negative                   NaN
# 73519        Delivered       5         Positive    Highly recommended
# 345424       Delivered       3          Neutral       Average quality
# 459325      In Transit       3          Neutral        Great product!
# 440594       Delivered       3          Neutral  Good value for money
# 916415       Delivered       1         Negative                   NaN
# 484335       Delivered       5         Positive                   NaN
#
#        coupon_used coupon_code campaign_source device_type traffic_source  \
# 501720          No         NaN      Google Ads      Mobile         Direct
# 384708          No         NaN           Email     Desktop         Search
# 578705          No         NaN       Affiliate      Mobile          Email
# 367462         Yes     CPN-KDH      Google Ads     Desktop       Referral
# 73519           No         NaN           Email      Mobile         Social
# 345424         Yes     CPN-PD9       Instagram      Tablet       Referral
# 459325          No         NaN      Google Ads     Desktop          Email
# 440594          No         NaN           Email     Desktop         Direct
# 916415          No         NaN           Email      Mobile         Social
# 484335         Yes     CPN-HVN       Affiliate      Tablet         Direct
#
#         session_duration_minutes  pages_visited abandoned_cart_before  \
# 501720                     23.40              4                    No
# 384708                     49.70              8                   Yes
# 578705                     20.60             19                   Yes
# 367462                     35.60              1                   Yes
# 73519                      52.90              9                    No
# 345424                     34.30              2                   Yes
# 459325                     31.80             13                   Yes
# 440594                     14.40              7                    No
# 916415                     28.10              7                    No
# 484335                     21.20             11                    No
#
#         fraud_risk_score  profit_margin_percent order_priority  \
# 501720             83.50                  43.77         Medium
# 384708              8.70                  44.25            Low
# 578705             45.60                  48.60           High
# 367462              0.40                  42.38           High
# 73519              92.50                  44.61           High
# 345424             85.20                  58.87         Medium
# 459325             83.80                  37.81            Low
# 440594             35.70                  25.51           High
# 916415             14.80                  45.01         Medium
# 484335             38.90                  36.48            Low
#
#        support_ticket_created
# 501720                     No
# 384708                     No
# 578705                    Yes
# 367462                    Yes
# 73519                      No
# 345424                     No
# 459325                     No
# 440594                     No
# 916415                    Yes
# 484335                     No

# %%
# Check the overall dataset dimensions: rows and columns.
ecommerce_df.shape
# Out:
# (1000123, 62)

# %%
# Print a concise summary of column types and non-null counts.
ecommerce_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000123 entries, 0 to 1000122
# Data columns (total 62 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   order_id                  1000123 non-null  object
#  1   order_date                1000123 non-null  object
#  2   order_year                1000123 non-null  int64
#  3   order_month               1000123 non-null  int64
#  4   order_day                 1000123 non-null  int64
#  5   order_hour                1000123 non-null  int64
#  6   order_minute              1000123 non-null  int64
#  7   order_second              1000123 non-null  int64
#  8   is_weekend                1000123 non-null  object
#  9   order_status              1000123 non-null  object
#  10  return_reason             99879 non-null    object
#  11  customer_id               1000123 non-null  object
#  12  customer_name             1000123 non-null  object
#  13  gender                    1000123 non-null  object
#  14  age                       1000123 non-null  int64
#  15  customer_segment          1000123 non-null  object
#  16  country                   1000123 non-null  object
#  17  city                      1000123 non-null  object
#  18  customer_loyalty_score    1000123 non-null  float64
#  19  total_orders_by_customer  1000123 non-null  int64
#  20  account_creation_date     1000123 non-null  object
#  21  product_id                1000123 non-null  object
#  22  product_name              1000123 non-null  object
#  23  category                  1000123 non-null  object
#  24  sub_category              1000123 non-null  object
#  25  brand                     1000123 non-null  object
#  26  product_rating_avg        1000123 non-null  float64
#  27  product_reviews_count     1000123 non-null  int64
#  28  stock_quantity            1000123 non-null  int64
#  29  unit_price_usd            1000123 non-null  float64
#  30  quantity                  1000123 non-null  int64
#  31  discount_percent          1000123 non-null  int64
#  32  discount_amount_usd       1000123 non-null  float64
#  33  total_price_usd           1000123 non-null  float64
#  34  cost_usd                  1000123 non-null  float64
#  35  profit_usd                1000123 non-null  float64
#  36  tax_usd                   1000123 non-null  float64
#  37  currency                  1000123 non-null  object
#  38  payment_method            1000123 non-null  object
#  39  payment_status            1000123 non-null  object
#  40  installment_plan          1000123 non-null  object
#  41  shipping_method           1000123 non-null  object
#  42  shipping_cost_usd         1000123 non-null  float64
#  43  delivery_days             1000123 non-null  int64
#  44  shipping_country          1000123 non-null  object
#  45  warehouse_location        1000123 non-null  object
#  46  delivery_status           1000123 non-null  object
#  47  rating                    1000123 non-null  int64
#  48  review_sentiment          1000123 non-null  object
#  49  customer_feedback         800506 non-null   object
#  50  coupon_used               1000123 non-null  object
#  51  coupon_code               500040 non-null   object
#  52  campaign_source           1000123 non-null  object
#  53  device_type               1000123 non-null  object
#  54  traffic_source            1000123 non-null  object
#  55  session_duration_minutes  1000123 non-null  float64
#  56  pages_visited             1000123 non-null  int64
#  57  abandoned_cart_before     1000123 non-null  object
#  58  fraud_risk_score          1000123 non-null  float64
#  59  profit_margin_percent     1000123 non-null  float64
#  60  order_priority            1000123 non-null  object
#  61  support_ticket_created    1000123 non-null  object
# dtypes: float64(12), int64(15), object(35)
# memory usage: 473.1+ MB

# %%
# Compute descriptive statistics
ecommerce_df.describe()
# Out:
#         order_year  order_month    order_day   order_hour  order_minute  \
# count 1,000,123.00 1,000,123.00 1,000,123.00 1,000,123.00  1,000,123.00
# mean      2,024.59         6.51        15.75        11.49         29.49
# std           0.58         3.45         8.80         6.92         17.31
# min       2,024.00         1.00         1.00         0.00          0.00
# 25%       2,024.00         4.00         8.00         5.00         14.00
# 50%       2,025.00         7.00        16.00        11.00         30.00
# 75%       2,025.00        10.00        23.00        17.00         44.00
# max       2,026.00        12.00        31.00        23.00         59.00
#
#        order_second          age  customer_loyalty_score  \
# count  1,000,123.00 1,000,123.00            1,000,123.00
# mean          29.49        46.49                   49.97
# std           17.33        16.73                   28.89
# min            0.00        18.00                    0.00
# 25%           14.00        32.00                   24.90
# 50%           29.00        46.00                   50.00
# 75%           44.00        61.00                   75.00
# max           59.00        75.00                  100.00
#
#        total_orders_by_customer  product_rating_avg  product_reviews_count  \
# count              1,000,123.00        1,000,123.00           1,000,123.00
# mean                      25.49                4.00               2,501.57
# std                       14.43                0.58               1,443.46
# min                        1.00                3.00                   0.00
# 25%                       13.00                3.50               1,253.00
# 50%                       25.00                4.00               2,503.00
# 75%                       38.00                4.50               3,752.00
# max                       50.00                5.00               5,000.00
#
#        stock_quantity  unit_price_usd     quantity  discount_percent  \
# count    1,000,123.00    1,000,123.00 1,000,123.00      1,000,123.00
# mean           499.81          147.02         3.00              8.50
# std            288.86          103.67         1.41              7.60
# min              0.00           10.00         1.00              0.00
# 25%            250.00           69.51         2.00              0.00
# 50%            500.00          125.11         3.00             10.00
# 75%            750.00          195.61         4.00             15.00
# max          1,000.00          500.00         5.00             25.00
#
#        discount_amount_usd  total_price_usd     cost_usd   profit_usd  \
# count         1,000,123.00     1,000,123.00 1,000,123.00 1,000,123.00
# mean                 37.48           403.24       242.31       160.93
# std                  56.78           370.13       226.72       161.93
# min                   0.00             7.53         4.03         0.70
# 25%                   0.00           139.02        82.45        50.69
# 50%                  16.91           290.19       172.53       108.79
# 75%                  49.26           545.76       326.45       214.64
# max                 624.71         2,499.75     1,743.70     1,495.75
#
#            tax_usd  shipping_cost_usd  delivery_days       rating  \
# count 1,000,123.00       1,000,123.00   1,000,123.00 1,000,123.00
# mean         30.25              12.50           7.51         3.00
# std          28.89               7.22           4.03         1.41
# min           0.43               0.00           1.00         1.00
# 25%          10.12               6.26           4.00         2.00
# 50%          21.28              12.50           8.00         3.00
# 75%          40.59              18.74          11.00         4.00
# max         245.59              25.00          14.00         5.00
#
#        session_duration_minutes  pages_visited  fraud_risk_score  \
# count              1,000,123.00   1,000,123.00      1,000,123.00
# mean                      30.51          10.51             49.96
# std                       17.03           5.77             28.85
# min                        1.00           1.00              0.00
# 25%                       15.70           6.00             25.00
# 50%                       30.50          11.00             50.00
# 75%                       45.30          16.00             74.90
# max                       60.00          20.00            100.00
#
#        profit_margin_percent
# count           1,000,123.00
# mean                   39.47
# std                    10.94
# min                     6.66
# 25%                    31.69
# 50%                    39.90
# 75%                    48.17
# max                    60.02

# %%
# Calculate and print the percentage of missing values per column.
print((ecommerce_df.isnull().sum() / ecommerce_df.shape[0] * 100).round(2).to_string())
# Out:
# order_id                    0.00
# order_date                  0.00
# order_year                  0.00
# order_month                 0.00
# order_day                   0.00
# order_hour                  0.00
# order_minute                0.00
# order_second                0.00
# is_weekend                  0.00
# order_status                0.00
# return_reason              90.01
# customer_id                 0.00
# customer_name               0.00
# gender                      0.00
# age                         0.00
# customer_segment            0.00
# country                     0.00
# city                        0.00
# customer_loyalty_score      0.00
# total_orders_by_customer    0.00
# account_creation_date       0.00
# product_id                  0.00
# product_name                0.00
# category                    0.00
# sub_category                0.00
# brand                       0.00
# product_rating_avg          0.00
# product_reviews_count       0.00
# stock_quantity              0.00
# unit_price_usd              0.00
# quantity                    0.00
# discount_percent            0.00
# discount_amount_usd         0.00
# total_price_usd             0.00
# cost_usd                    0.00
# profit_usd                  0.00
# tax_usd                     0.00
# currency                    0.00
# payment_method              0.00
# payment_status              0.00
# installment_plan            0.00
# shipping_method             0.00
# shipping_cost_usd           0.00
# delivery_days               0.00
# shipping_country            0.00
# warehouse_location          0.00
# delivery_status             0.00
# rating                      0.00
# review_sentiment            0.00
# customer_feedback          19.96
# coupon_used                 0.00
# coupon_code                50.00
# campaign_source             0.00
# device_type                 0.00
# traffic_source              0.00
# session_duration_minutes    0.00
# pages_visited               0.00
# abandoned_cart_before       0.00
# fraud_risk_score            0.00
# profit_margin_percent       0.00
# order_priority              0.00
# support_ticket_created      0.00

# %% [markdown]
# Notable missing values were observed in **``return_season``**, **``customer_feedback``**, and **``coupon_code``**.

# %%
# Total of duplicate rows
duplicates_row = ecommerce_df.duplicated().sum()
print(f'Total of Duplicate Rows : {duplicates_row}')
# Out:
# Total of Duplicate Rows : 0

# %%
# True = unique identifier candidate
print(ecommerce_df.apply(lambda col: col.is_unique).to_string())
# Out:
# order_id                    False
# order_date                   True
# order_year                  False
# order_month                 False
# order_day                   False
# order_hour                  False
# order_minute                False
# order_second                False
# is_weekend                  False
# order_status                False
# return_reason               False
# customer_id                 False
# customer_name               False
# gender                      False
# age                         False
# customer_segment            False
# country                     False
# city                        False
# customer_loyalty_score      False
# total_orders_by_customer    False
# account_creation_date       False
# product_id                  False
# product_name                False
# category                    False
# sub_category                False
# brand                       False
# product_rating_avg          False
# product_reviews_count       False
# stock_quantity              False
# unit_price_usd              False
# quantity                    False
# discount_percent            False
# discount_amount_usd         False
# total_price_usd             False
# cost_usd                    False
# profit_usd                  False
# tax_usd                     False
# currency                    False
# payment_method              False
# payment_status              False
# installment_plan            False
# shipping_method             False
# shipping_cost_usd           False
# delivery_days               False
# shipping_country            False
# warehouse_location          False
# delivery_status             False
# rating                      False
# review_sentiment            False
# customer_feedback           False
# coupon_used                 False
# coupon_code                 False
# campaign_source             False
# device_type                 False
# traffic_source              False
# session_duration_minutes    False
# pages_visited               False
# abandoned_cart_before       False
# fraud_risk_score            False
# profit_margin_percent       False
# order_priority              False
# support_ticket_created      False

# %% [markdown]
# >Based on the data, it appears that the dataset does not have a suitable unique identifier column. Although order_date contains unique values, it is not a reliable unique identifier since it is a timestamp and may not remain unique in real-world scenarios.
